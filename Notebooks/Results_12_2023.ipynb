# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from tqdm.auto import tqdm  # for easy progress bar
import os
from util import get_trial_res, show_results, compare_results
import json
# folder where the results are stored: 
res_dir = "../../../../../surfdrive/Documents/Research/Result"
colors = [i for i in mcolors.TABLEAU_COLORS.keys()]

# %%
case = 'lin_case5_sacd'
seeds = 5
summary, res_sacd_lin = show_results(res_dir, case, seeds, name='Linear')
summary
# Out:
# dir:	 /scratch-local/evandersar.4597460/evds_output_dir
# name:	 gnn_case5
# load_agent:
# seed:	 0
# case:	 5
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 5000
# eval_steps:	 100
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 sacd
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 5e-05
# gamma:	 0.995
# batch_size:	 64
# update_start:	 4
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.2
# entropy:	 0.01
# lambda:	 0.95
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         864.0                    0.0  99.824830                  25.0
# 1         864.0                    6.0  99.940746                  14.0
# 2         864.0                    3.0  99.992986                  25.0
# ...

# %%
case = 'gnn_real_case5_sacd'
seeds = 5
summary, res_sacd_gnn = show_results(res_dir, case, seeds, name='GNN')
summary
# Out:
# dir:	 /scratch-local/evandersar.4597800/evds_output_dir
# name:	 gnn_real_case5
# load_agent:
# seed:	 0
# case:	 5
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 5000
# eval_steps:	 100
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 sacd
# network:	 gnn
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 5e-05
# gamma:	 0.995
# batch_size:	 64
# update_start:	 4
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.2
# entropy:	 0.01
# lambda:	 0.95
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         864.0                    0.0  99.940746                   0.0
# 1         864.0                   24.0  99.952612                  24.0
# 2         864.0                   11.0  99.977708                  11.0
# ...

# %%
case = 'test_case5_sacd_emb'
seeds = 5
summary, res_sacd_gnn = show_results(res_dir, case, seeds, name='GNN')
summary
# Out:
# dir:	 /scratch-local/evandersar.4597456/evds_output_dir
# name:	 test_case5
# load_agent:
# seed:	 0
# case:	 5
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 5000
# eval_steps:	 100
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 sacd_emb
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 5e-05
# gamma:	 0.995
# batch_size:	 64
# update_start:	 4
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.2
# entropy:	 0.01
# lambda:	 0.95
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         864.0                    4.0  99.956174                   4.0
# 1         864.0                    0.0  99.952612                   9.0
# 2         864.0                    0.0  99.923370                  48.0
# ...

# %%
case = 'gnn_real_case5_sacd_emb'
seeds = 5
summary, res_sacd_gnn = show_results(res_dir, case, seeds, name='GNN')
summary
# Out:
# dir:	 /scratch-local/evandersar.4597804/evds_output_dir
# name:	 gnn_real_case5
# load_agent:
# seed:	 0
# case:	 5
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 5000
# eval_steps:	 100
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 sacd_emb
# network:	 gnn
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 5e-05
# gamma:	 0.995
# batch_size:	 64
# update_start:	 4
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.2
# entropy:	 0.01
# lambda:	 0.95
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         864.0                   17.0  99.601568                  23.0
# 1         864.0                    8.0  99.952612                  23.0
# 2         864.0                   21.0  99.966567                  33.0
# ...

# %%
case = 'lin_case14_ppo'
seeds = 1
summary, res_sacd_gnn = show_results(res_dir, case, seeds, name='Linear')
summary
# Out:
# dir:	 /scratch-local/evandersar.4597407/evds_output_dir
# name:	 gnn_case14
# load_agent:
# seed:	 0
# case:	 14
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.003
# gamma:	 0.995
# batch_size:	 64
# update_start:	 6
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 1e-05
# lambda:	 0.9
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         142.2                    2.0   6.806993                   2.0

# %%
case = 'lin_tr13pars_case14_ppo'
seeds = 1
summary, res_sacd_gnn = show_results(res_dir, case, seeds, name='Linear_tr13Pars')
summary
# Out:
# dir:	 /scratch-local/evandersar.4597327/evds_output_dir
# name:	 gnn_tr13pars_case14
# load_agent:
# seed:	 0
# case:	 14
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.0013
# gamma:	 0.996
# batch_size:	 16
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         864.0                   23.0  97.963289                  67.0

# %%
case = 'gnn_real_case14_ppo'
seeds = 1
summary, res_sacd_gnn = show_results(res_dir, case, seeds, name='GNN')
summary
# Out:
# dir:	 /scratch-local/evandersar.4597625/evds_output_dir
# name:	 gnn_real_case14
# load_agent:
# seed:	 0
# case:	 14
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 gnn
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.003
# gamma:	 0.995
# batch_size:	 64
# update_start:	 6
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 1e-05
# lambda:	 0.9
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         419.4                   35.0  44.049562                  16.0
