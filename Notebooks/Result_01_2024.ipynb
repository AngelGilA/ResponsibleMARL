# %%
import sys
sys.path.append('../')
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from tqdm.auto import tqdm  # for easy progress bar
import os
import scienceplots
from util import get_trial_res, show_results, compare_results, plot_fullep_score
import json
# folder where the results are stored: 
res_dir = "../../../../../surfdrive/Documents/Research/Result"
colors = [i for i in mcolors.TABLEAU_COLORS.keys()]

# %%
case = 'case_5_FullScoreTest_gnn_ppo'
seeds = 5
summary, res_ppo_gnn = show_results(res_dir, case, seeds, name='gnn - Margin RW')
summary
# Out:
# dir:	 /scratch-local/evandersar.4868815/evds_output_dir
# name:	 FullScoreTest_gnn
# load_agent:
# seed:	 0
# case:	 5
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 5000
# eval_steps:	 100
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 gnn
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.003
# gamma:	 0.95
# batch_size:	 32
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.2
# entropy:	 0.01
# lambda:	 0.95
#       Max steps  Agent updates (steps)   Best mean  Agent updates (mean)
# seed
# 0         864.0                    2.0   99.896746                   7.0
# 1         864.0                    4.0   99.968507                  26.0
# 2         864.0                    0.0   99.968507                   0.0
# ...

# %%
full_res_ppo_gnn = plot_fullep_score(res_dir, case, seeds, name='PPO - GNN - full Episode score - Margin RW', nb_steps=5000)

# %%
cases = ["PPO - partial score","PPO - full score"]
figure = compare_results(cases, [res_ppo_gnn, full_res_ppo_gnn], style=['science', 'grid', 'no-latex'], nb_steps=5000)
figure.set_size_inches(8,6)

# %%
case = 'case_5_FullScoreTest_lin_ppo'
seeds = 5
summary, res_sacd_lin = show_results(res_dir, case, seeds, name='lin - Margin RW')
summary
# Out:
# dir:	 /scratch-local/evandersar.4868545/evds_output_dir
# name:	 FullScoreTest_lin
# load_agent:
# seed:	 0
# case:	 5
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 5000
# eval_steps:	 100
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.003
# gamma:	 0.95
# batch_size:	 32
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.2
# entropy:	 0.01
# lambda:	 0.95
#       Max steps  Agent updates (steps)   Best mean  Agent updates (mean)
# seed
# 0         864.0                    5.0   99.975292                  39.0
# 1         864.0                    2.0  100.000000                  18.0
# 2         864.0                    2.0  100.000000                  31.0
# ...

# %%
res_5_fullep_lin = plot_fullep_score(res_dir, case, seeds, name='PPO Linear Full Episode score - Margin RW', nb_steps=5000)

# %%
case = 'case_14_TestFull_GPU_tr13_gnn_ppo'
seeds = 1
summary, res_case14_gnne = show_results(res_dir, case, seeds, name='Params tr13 - gnn with GPU - Margin RW')
summary
# Out:
# dir:	 /scratch-local/evandersar.4888822/evds_output_dir
# name:	 TestFull_GPU_tr13_gnn
# load_agent:
# seed:	 0
# case:	 14
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 gnn
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.0013
# gamma:	 0.995
# batch_size:	 16
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         208.0                    1.0  -3.384679                   1.0

# %%
case = 'case_14_TestFull_tr13_gnn_ppo'
seeds = 1
summary, res_case14_gnne = show_results(res_dir, case, seeds, name='Params tr13 - gnn - Margin RW')
summary
# Out:
# dir:	 /scratch-local/evandersar.4888813/evds_output_dir
# name:	 TestFull_tr13_gnn
# load_agent:
# seed:	 0
# case:	 14
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 gnn
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.0013
# gamma:	 0.995
# batch_size:	 16
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         419.4                    2.0  37.800369                   2.0

# %%
case = 'case_14_TestFull_tr13_lin_ppo'
seeds = 1
summary, res_case14_lin = show_results(res_dir, case, seeds, name='Params tr13 - lin with GPU - Margin RW')
summary
# Out:
# dir:	 /scratch-local/evandersar.4895725/evds_output_dir
# name:	 TestFull_tr13_lin
# load_agent:
# seed:	 0
# case:	 14
# reward:	 margin
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.0013
# gamma:	 0.995
# batch_size:	 16
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         795.0                   18.0  84.954945                  18.0

# %%
full_res_case14 = plot_fullep_score(res_dir, case, seeds, name='PPO Linear Full Episode score - Margin RW', nb_steps=100000)

# %%
cases = ["case14 - PPO - lin","case 14 - PPO - lin - full score"]
figure = compare_results(cases, [res_case14_lin, full_res_case14], style=['science', 'grid', 'no-latex'], nb_steps = 100_000)
figure.set_size_inches(8,6)

# %%
case = 'case_14_TestFull_tr13LossRW_gnn_ppo'
seeds = 1
summary, res_case14_lin = show_results(res_dir, case, seeds, name='Lin - Loss RW')
summary
# Out:
# dir:	 /scratch-local/evandersar.4909015/evds_output_dir
# name:	 TestFull_tr13LossRW_gnn
# load_agent:
# seed:	 0
# case:	 14
# reward:	 loss
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.0013
# gamma:	 0.995
# batch_size:	 16
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         864.0                   49.0  98.040087                  81.0

# %%
case14_PPO_lin_res = plot_fullep_score(res_dir, case, seeds, name='PPO - LINEAR - Full Episode score - Loss RW', nb_steps=100000)

# %%
case = 'case_14_TestFull_realtr13LossRW_gnn_ppo'
seeds = 1
summary, res_case14_lin_tr13 = show_results(res_dir, case, seeds, name='Params tr13 - Linear - Loss RW')
summary
# Out:
# dir:	 /scratch-local/evandersar.4909084/evds_output_dir
# name:	 TestFull_realtr13LossRW_gnn
# load_agent:
# seed:	 0
# case:	 14
# reward:	 loss
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.0013
# gamma:	 0.996
# batch_size:	 16
# update_start:	 5
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91
#       Max steps  Agent updates (steps)  Best mean  Agent updates (mean)
# seed
# 0         864.0                   10.0  98.033914                  31.0

# %%
PPO_lin_tr13 = plot_fullep_score(res_dir, case, seeds, name='PPO - Linear - Full Episode score - Loss RW', nb_steps=100000)

# %%
# folder where the results are stored: 
res_dir = "../result"

# %%
case = 'case_14_FullEp_param13_ppo'
seeds = 1
res_14_tr13_fullEp = plot_fullep_score(res_dir, case, seeds, name='PPO - GNN - Full Episode train & score - Loss RW', nb_steps=100000)

# %%
case = 'case_14_FullEp_ppo'
seeds = 1
res_14_FullEpp = plot_fullep_score(res_dir, case, seeds, name='PPO GNN - Full Ep train & score - Loss RW', nb_steps=100000)

# %%
script_path = os.path.join(res_dir, f"{case}_0")
with open(os.path.join(script_path, "param.json"), "r") as f:
    params = json.load(f)
void = [print(f"{key}:\t {params.get(key)}") for key in params.keys()]
# Out:
# dir:
# name:	 FullEp
# load_agent:
# seed:	 0
# case:	 14
# reward:	 loss
# train_full:	 True
# test_full:	 False
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 gnn
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.003
# gamma:	 0.995
# batch_size:	 16
# update_start:	 6
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91

# %%
case = 'case_14_FullEp_lin_ppo'
seeds = 1
res_14_FullEpp = plot_fullep_score(res_dir, case, seeds, name='PPO Lin - Full Ep train & score - Loss RW', nb_steps=100000)

# %%
script_path = os.path.join(res_dir, f"{case}_0")
with open(os.path.join(script_path, "param.json"), "r") as f:
    params = json.load(f)
void = [print(f"{key}:\t {params.get(key)}") for key in params.keys()]
# Out:
# dir:
# name:	 FullEp_lin
# load_agent:
# seed:	 0
# case:	 14
# reward:	 loss
# train_full:	 True
# test_full:	 False
# gpuid:	 0
# memlen:	 50000
# nb_steps:	 100000
# eval_steps:	 1000
# mask:	 3
# max_reward:	 10
# input:	 ['p_i', 'r', 'o', 'd', 'm']
# forecast:	 0
# danger:	 0.9
# middle_agent:	 capa
# agent:	 ppo
# network:	 lin
# head_number:	 8
# state_dim:	 128
# n_history:	 6
# dropout:	 0.0
# n_layers:	 3
# lr:	 0.003
# gamma:	 0.995
# batch_size:	 16
# update_start:	 6
# rule:	 c
# threshold:	 0.1
# target_update:	 1
# tau:	 0.001
# target_entropy_scale:	 0.98
# epsilon:	 0.18
# entropy:	 0.05
# lambda:	 0.91
